# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
linkedin_data = pd.read_csv("C:\\Users\\dhima\\Downloads\\linkedin-reviews.csv")

# %%
linkedin_data
# Out:
#                                                 Review  Rating
# 0    Does absolutely nothing for a LinkedIn beginne...       1
# 1                              Force close(galaxy tab)       1
# 2    Slow and it tries to upload your contacts with...       1
# 3    Add ability to customize the profile and move ...       4
# 4    Good app, but it's a pain that it's not possib...       4
# ..                                                 ...     ...
# 697  Can't trust, Going to uninstall just for that ...       1
# 698  It really gets me linked in with my friends. H...       5
# 699  It lacks most of what makes the other social n...       4
# 700  Really disappointed in the new version. Seems ...       2
# 701  One of the best looking and well designed apps...       5
#
# [702 rows x 2 columns]

# %%
# Display the first few rows
print(linkedin_data.head())
# Out:
#                                               Review  Rating
# 0  Does absolutely nothing for a LinkedIn beginne...       1
# 1                            Force close(galaxy tab)       1
# 2  Slow and it tries to upload your contacts with...       1
# 3  Add ability to customize the profile and move ...       4
# 4  Good app, but it's a pain that it's not possib...       4

# %%
print(linkedin_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  702 non-null    object
#  1   Rating  702 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 11.1+ KB
# None

# %%
# Plotting the distribution of ratings
sns.set(style="whitegrid")
plt.figure(figsize=(9, 5))
sns.countplot(data=linkedin_data, x='Rating')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Calculating the length of each review
linkedin_data['Review Length'] = linkedin_data['Review'].apply(len)

# Plotting the distribution of review lengths
plt.figure(figsize=(9, 6))
sns.histplot(linkedin_data['Review Length'], bins=50, kde=True)
plt.title('Distribution of Review Lengths')
plt.xlabel('Length of Review')
plt.ylabel('Count')
plt.show()

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\dhima\desktop\anaconda\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\dhima\desktop\anaconda\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: tqdm in c:\users\dhima\desktop\anaconda\lib\site-packages (from nltk>=3.8->textblob) (4.64.1)
# Requirement already satisfied: click in c:\users\dhima\desktop\anaconda\lib\site-packages (from nltk>=3.8->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\dhima\desktop\anaconda\lib\site-packages (from nltk>=3.8->textblob) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dhima\desktop\anaconda\lib\site-packages (from nltk>=3.8->textblob) (2022.7.9)
# Requirement already satisfied: colorama in c:\users\dhima\desktop\anaconda\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)

# %%
from textblob import TextBlob

def textblob_sentiment_analysis(review):
    # Analyzing the sentiment of the review
    sentiment = TextBlob(review).sentiment
    # Classifying based on polarity
    if sentiment.polarity > 0.1:
        return 'Positive'
    elif sentiment.polarity < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

# Applying TextBlob sentiment analysis to the reviews
linkedin_data['Sentiment'] = linkedin_data['Review'].apply(textblob_sentiment_analysis)

# Displaying the first few with the sentiments
print(linkedin_data.head())
# Out:
#                                               Review  Rating  Review Length  \
# 0  Does absolutely nothing for a LinkedIn beginne...       1             80
# 1                            Force close(galaxy tab)       1             23
# 2  Slow and it tries to upload your contacts with...       1             61
# 3  Add ability to customize the profile and move ...       4             90
# 4  Good app, but it's a pain that it's not possib...       4            133
#
#   Sentiment
# 0  Negative
# 1   Neutral
# 2  Negative
# 3   Neutral
# 4  Positive

# %%
# Analyzing the distribution of sentiments
sentiment_distribution = linkedin_data['Sentiment'].value_counts()

# Plotting the distribution of sentiments
plt.figure(figsize=(9, 5))
sns.barplot(x=sentiment_distribution.index, y=sentiment_distribution.values)
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=linkedin_data, x='Rating', hue='Sentiment')
plt.title('Sentiment Distribution Across Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.legend(title='Sentiment')

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\dhima\desktop\anaconda\lib\site-packages (1.9.3)
# Requirement already satisfied: matplotlib in c:\users\dhima\desktop\anaconda\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in c:\users\dhima\desktop\anaconda\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\dhima\desktop\anaconda\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dhima\desktop\anaconda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dhima\desktop\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhima\desktop\anaconda\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhima\desktop\anaconda\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dhima\desktop\anaconda\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhima\desktop\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhima\desktop\anaconda\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\dhima\desktop\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

# Function to generate word cloud for each sentiment
def generate_word_cloud(sentiment):
    text = ' '.join(review for review in linkedin_data[linkedin_data['Sentiment'] == sentiment]['Review'])
    wordcloud = WordCloud(width=800, height=400, background_color ='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for {sentiment} Reviews')
    plt.axis('off')
    plt.show()

# Generating word clouds for each sentiment
for sentiment in ['Positive','Negative','Neutral']:
    generate_word_cloud(sentiment)

# %%
custom_lexicon = {
  "intuitive": "positive",
  "buggy": "negative",
  "user-friendly": "positive",
  "disappointed": "negative",
  "crashes often": "negative",
  # Add more entries here...
}

# %%
def sentiment_analysis(review):
  sentiment = TextBlob(review).sentiment

  # Check for custom lexicon words
  for word, sentiment_value in custom_lexicon.items():
    if word.lower() in review.lower():  # Consider case-insensitivity
      sentiment.polarity += 0.2 * sentiment_value  # Adjust weight as needed

  if sentiment.polarity > 0.1:
    return "Positive"
  elif sentiment.polarity < -0.1:
    return "Negative"
  else:
    return "Neutral"

# %%
# Add a sentiment column with the custom lexicon
linkedin_data["Sentiment"] = linkedin_data["Review"].apply(sentiment_analysis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 # Add a sentiment column with the custom lexicon
# ----> 2 linkedin_data["Sentiment"] = linkedin_data["Review"].apply(sentiment_analysis)
#
# File ~\Desktop\anaconda\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\Desktop\anaconda\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\Desktop\anaconda\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\Desktop\anaconda\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[43], line 7, in sentiment_analysis(review)
#       5 for word, sentiment_value in custom_lexicon.items():
#       6   if word.lower() in review.lower():  # Consider case-insensitivity
# ----> 7     sentiment.polarity += 0.2 * sentiment_value  # Adjust weight as needed
#       9 if sentiment.polarity > 0.1:
#      10   return "Positive"
#
# TypeError: can't multiply sequence by non-int of type 'float'
